# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/raw/heart_disease.csv")
df.head()
# Out:
# Matplotlib is building the font cache; this may take a moment.
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  target
# 0    3.0  0.0   6.0       0
# 1    2.0  3.0   3.0       2
# 2    2.0  2.0   7.0       1
# 3    3.0  0.0   3.0       0
# 4    1.0  0.0   3.0       0

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
#  13  target    303 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 33.3 KB
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# ...

# %%
df["target"] = df["target"].apply(lambda x: 1 if x > 0 else 0)

sns.countplot(x="target", data=df)
plt.title("Target Class Distribution")
plt.show()

# %%
df.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), cmap="coolwarm", annot=False)
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# Reproducible code to load data in run time is under src/data/load_data.py
#
# Using this run time code, data is downloaded and stored to data/raw/heart_disease.csv
#
# Exploratory Data Analysis on this data which includes viewing Target and Feature distributions and Correlation heatmap is completed
